# %%
# !pip install keras-ocr
# Out:
# ...
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19583 sha256=190750ab763f7e924b6a67efe73bfd65420bc700adeb0b8845ce064e1ac4bb3a
#   Stored in directory: c:\users\artimarthak\appdata\local\pip\cache\wheels\2d\f0\a8\1094fca7a7e5d0d12ff56e0c64675d72aa5cc81a5fc200e849
# Successfully built validators
# ...

# %%
import keras_ocr
from matplotlib import pyplot as plt
import cv2

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for C:\Users\ArtiMarthak\.keras-ocr\craft_mlt_25k.h5
# Looking for C:\Users\ArtiMarthak\.keras-ocr\crnn_kurapan.h5

# %%
# img = 'C:/Users/ArtiMarthak/Downloads/cv/nick/EasyOCR-main/EasyOCR-main/data/surf.jpeg'
img = cv2.imread('C:/Users/ArtiMarthak/Downloads/cv/nick/EasyOCR-main/EasyOCR-main/data/surf.jpeg')

# %%
img.shape
# Out:
# (166, 304, 3)

# %%
prediction_groups = pipeline.recognize(img)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ARTIMA~1\AppData\Local\Temp/ipykernel_5500/617147004.py in <module>
# ----> 1 prediction_groups = pipeline.recognize(img)
#
# ~\anaconda3\lib\site-packages\keras_ocr\pipeline.py in recognize(self, images, detection_kwargs, recognition_kwargs)
#      60         if recognition_kwargs is None:
#      61             recognition_kwargs = {}
# ---> 62         box_groups = self.detector.detect(images=images, **detection_kwargs)
#      63         prediction_groups = self.recognizer.recognize_from_boxes(
#      64             images=images, box_groups=box_groups, **recognition_kwargs
#
# ~\anaconda3\lib\site-packages\keras_ocr\detection.py in detect(self, images, detection_threshold, text_threshold, link_threshold, size_threshold, **kwargs)
#     775             size_threshold: The minimum area for a word.
#     776         """
# ...

# %%
#new
import keras_ocr
from matplotlib import pyplot as plt

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for C:\Users\ArtiMarthak\.keras-ocr\craft_mlt_25k.h5
# Looking for C:\Users\ArtiMarthak\.keras-ocr\crnn_kurapan.h5

# %%
images = [keras_ocr.tools.read(url) for url in['C:/Users/ArtiMarthak/Downloads/cv/nick/EasyOCR-main/EasyOCR-main/data/surf.jpeg']]

# %%
# print(images[0])

# %%
prediction_groups = pipeline.recognize(images)
# Out:
# ...
# 1/1 [==============================] - 0s 125ms/step

# %%
# predicted_image_1 =  prediction_groups[0]
# for text,box in predicted_image_1:
#     print(box)
# Out:
# [[ 31.665924  30.383066]
#  [281.0432    34.105118]
#  [279.5029   137.30602 ]
#  [ 30.12561  133.58397 ]]

# %%
# plt.imshow(box)

# %%
len(images)
# Out:
# 1

# %%
 # plt.subplots(len(images),figsize=(5,5))
for ax,image,predictions in zip(axs,images,prediction_groups):
    keras_ocr.tools.drawAnnotations(image = image,predictions=predictions,ax=ax)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ARTIMA~1\AppData\Local\Temp/ipykernel_5500/2122141967.py in <module>
#       1 # plt.subplots(len(images),figsize=(5,5))
# ----> 2 for ax,image,predictions in zip(axs,images,prediction_groups):
#       3    keras_ocr.tools.drawAnnotations(image = image,predictions=predictions,ax=ax)
#
# TypeError: 'AxesSubplot' object is not iterable

# %%
predicted_image = prediction_groups[1]
for text, box in predicted_image:
    print(text)

# %%
#Tesseract
# !pip install pytesseract

# %%
import pytesseract
import cv2

# %%
# pytesseract.pytesseract.tesseract_cmd = r''

# %%
img_tess = cv2.imread('C:/Users/ArtiMarthak/Downloads/cv/nick/EasyOCR-main/EasyOCR-main/data/surf.jpeg')

# %%
img_tess.shape
# Out:
# (166, 304, 3)

# %%
plt.imshow(img_tess)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
text1 = pytesseract.image_to_string(img_tess)
print(text1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     254     try:
# --> 255         proc = subprocess.Popen(cmd_args, **subprocess_args())
#     256     except OSError as e:
#
# ~\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# ...
